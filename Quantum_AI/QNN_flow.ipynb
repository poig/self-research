# %% [markdown]
# # Quantum-AI flow
#
# The component we need is
#
# 1) quantum neural network circuit - various ansatz structure
#
# 2) quantum relu - approximate with Chebyshev polynomial in a range
#
# 3) quantum optimizer - muon optimizer which are natively matrix
#
# 4) quantum gradient decent -  that can calculate backprop to perform learning
#
# 5)

# %% [markdown]
# ## Quantum neural network

# %% [markdown]
# ## Quantum relu

# %% [markdown]
# ## Muon optimizer with quantum circuit

# %% [markdown]
# ## quantum gradient decent

# %% [markdown]
# ## full neural network Quantum training
